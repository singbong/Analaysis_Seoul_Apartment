# %% [markdown]
# # merge 데이터 전처리

# %%
import pandas as pd
import numpy as np
df_trd= pd.read_feather("../data/make_data/df_trd_merged.feather")
df_anc= pd.read_feather("../data/make_data/df_anc_merged.feather")
df_mst= pd.read_feather("../data/make_data/df_mst.feather")
df_hkd= pd.read_feather("../data/make_data/df_hkd.feather")
df_soc= pd.read_feather("../data/make_data/df_soc.feather")

# %%
df_trd.columns
# Out:
# Index(['아파트코드', '아파트명', '도로명주소', '법정동코드', '기준년월', '면적코드', '거래량', '누적거래량',
#        '회전율', '면적코드별최소실거래가',
#        ...
#        '아파트단지내표고최고값', '아파트단지인근표고평균값', '아파트단지인근표고최저값', '아파트단지인근표고최고값',
#        '근접 고도 지점 거리', 'cpi', '경제심리지수(원계열)', '기존_가계대출', '신규_가계대출', '기준금리'],
#       dtype='object', length=113)

# %%
df_trd['부속복리시설'] = df_trd['부속복리시설'].fillna('empty')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_seq_items', None)

df_trd.columns
# Out:
# Index(['아파트코드', '아파트명', '도로명주소', '법정동코드', '기준년월', '면적코드', '거래량', '누적거래량',
#        '회전율', '면적코드별최소실거래가', '면적코드별최대실거래가', '면적코드별평균실거래가', '면적코드별중위실거래가',
#        '최근거래일자', '거래동향', '인근아파트거래동향', '해당읍면동거래동향', '경도', '위도', '기준연도', '세대수',
#        '사용승인일자', '분양유형', '동수', '복도유형', '시공기업명', '건물구조', '승강기수', '지상주차대수',
#        '지하주차대수', 'CCTV수', '부속복리시설', '학군정보', '교차집계구총인구수', '교차집계구생산인구수',
#        '교차집계구유소년인구수', '교차집계구노년인구수', '인구밀도', '인구밀도지표', '총부양비', '유소년부양비',
#        '노년부양비', '노령화지수', '연령구조지표', '지하철역까지_거리', '지하철역명', '호선', '공원수', '공원총면적',
#        '환경생활지수', '환경평가점수', '아파트단지내경사도평균값', '아파트단지내경사도최저값', '아파트단지내경사도최고값',
#        '아파트단지인근경사도평균값', '아파트단지인근경사도최저값', '아파트단지인근경사도최고값', '차량접근가능시설수',
#        '5분_car', '10분_car', '15분_car', '20분_car', '25분_car', '30분_car',
#        '35분_car', '40분_car', '45분_car', '50분_car', '55분_car', '60분_car',
#        '도보접근가능시설수', '1분_walk', '2분_walk', '3분_walk', '4분_walk', '5분_walk',
#        '6분_walk', '7분_walk', '8분_walk', '9분_walk', '10분_walk', '11분_walk',
#        '12분_walk', '13분_walk', '14분_walk', '15분_walk', '16분_walk', '17분_walk',
#        '18분_walk', '19분_walk', '20분_walk', '21분_walk', '22분_walk', '23분_walk',
#        '24분_walk', '25분_walk', '26분_walk', '27분_walk', '28분_walk', '29분_walk',
#        '30분_walk', '아파트단지내표고평균값', '아파트단지내표고최저값', '아파트단지내표고최고값', '아파트단지인근표고평균값',
#        '아파트단지인근표고최저값', '아파트단지인근표고최고값', '근접 고도 지점 거리', 'cpi', '경제심리지수(원계열)',
#        '기존_가계대출', '신규_가계대출', '기준금리'],
#       dtype='object')

# %%
df_trd['15_car'] = df_trd['5분_car'] + df_trd['10분_car'] + df_trd['15분_car']
df_trd['30_car'] = df_trd['15_car'] + df_trd['20분_car'] + df_trd['25분_car'] + df_trd['30분_car']
df_trd['45_car'] = df_trd['30_car'] + df_trd['35분_car'] + df_trd['40분_car'] + df_trd['45분_car']
df_trd['60_car'] = df_trd['45_car'] + df_trd['50분_car'] + df_trd['55분_car'] + df_trd['60분_car']
df_trd['5_walk'] = df_trd['1분_walk'] + df_trd['2분_walk'] + df_trd['3분_walk'] + df_trd['4분_walk'] + df_trd['5분_walk']
df_trd['10_walk'] = df_trd['5_walk'] + df_trd['6분_walk'] + df_trd['7분_walk'] + df_trd['8분_walk'] + df_trd['9분_walk'] + df_trd['10분_walk']
df_trd['20_walk'] = df_trd['10_walk'] + df_trd['11분_walk'] + df_trd['12분_walk'] + df_trd['13분_walk'] + df_trd['14분_walk'] + df_trd['15분_walk'] + df_trd['16분_walk'] + df_trd['17분_walk'] + df_trd['18분_walk'] + df_trd['19분_walk'] + df_trd['20분_walk']
df_trd['30_walk'] = df_trd['20_walk'] + df_trd['21분_walk'] + df_trd['22분_walk'] + df_trd['23분_walk'] + df_trd['24분_walk'] + df_trd['25분_walk'] + df_trd['26분_walk'] + df_trd['27분_walk'] + df_trd['28분_walk'] + df_trd['29분_walk'] + df_trd['30분_walk']

# %%
df_trd.drop(columns=[ '5분_car', '10분_car', '15분_car', '20분_car', '25분_car', '30분_car',
       '35분_car', '40분_car', '45분_car', '50분_car', '55분_car', '60분_car',
       '도보접근가능시설수', '1분_walk', '2분_walk', '3분_walk', '4분_walk', '5분_walk',
       '6분_walk', '7분_walk', '8분_walk', '9분_walk', '10분_walk', '11분_walk',
       '12분_walk', '13분_walk', '14분_walk', '15분_walk', '16분_walk', '17분_walk',
       '18분_walk', '19분_walk', '20분_walk', '21분_walk', '22분_walk', '23분_walk',
       '24분_walk', '25분_walk', '26분_walk', '27분_walk', '28분_walk', '29분_walk',
       '30분_walk','경도','위도'],axis=1, inplace=True)

# %%
df_trd['자치구명'] = df_trd['도로명주소'].apply(lambda x: x.split(' ')[1])

# %%
df_trd = df_trd[df_trd['거래량']>0]

# %%
df_trd.columns
# Out:
# Index(['아파트코드', '아파트명', '도로명주소', '법정동코드', '기준년월', '면적코드', '거래량', '누적거래량',
#        '회전율', '면적코드별최소실거래가', '면적코드별최대실거래가', '면적코드별평균실거래가', '면적코드별중위실거래가',
#        '최근거래일자', '거래동향', '인근아파트거래동향', '해당읍면동거래동향', '기준연도', '세대수', '사용승인일자',
#        '분양유형', '동수', '복도유형', '시공기업명', '건물구조', '승강기수', '지상주차대수', '지하주차대수',
#        'CCTV수', '부속복리시설', '학군정보', '교차집계구총인구수', '교차집계구생산인구수', '교차집계구유소년인구수',
#        '교차집계구노년인구수', '인구밀도', '인구밀도지표', '총부양비', '유소년부양비', '노년부양비', '노령화지수',
#        '연령구조지표', '지하철역까지_거리', '지하철역명', '호선', '공원수', '공원총면적', '환경생활지수',
#        '환경평가점수', '아파트단지내경사도평균값', '아파트단지내경사도최저값', '아파트단지내경사도최고값',
#        '아파트단지인근경사도평균값', '아파트단지인근경사도최저값', '아파트단지인근경사도최고값', '차량접근가능시설수',
#        '아파트단지내표고평균값', '아파트단지내표고최저값', '아파트단지내표고최고값', '아파트단지인근표고평균값',
#        '아파트단지인근표고최저값', '아파트단지인근표고최고값', '근접 고도 지점 거리', 'cpi', '경제심리지수(원계열)',
#        '기존_가계대출', '신규_가계대출', '기준금리', '15_car', '30_car', '45_car', '60_car',
#        '5_walk', '10_walk', '20_walk', '30_walk', '자치구명'],
#       dtype='object')

# %%
trd_col = df_trd.isna().sum()
print(len(df_trd))
trd_col[trd_col>0]
# Out:
# 29335
# 거래동향           8358
# 인근아파트거래동향      1047
# 해당읍면동거래동향       637
# 세대수              85
# 사용승인일자          140
# 분양유형           8695
# 동수              979
# 복도유형           8698
# 시공기업명          8717
# 건물구조           1461
# 승강기수            979
# 지상주차대수         8906
# 지하주차대수         8912
# CCTV수          8912
# 학군정보             15
# 교차집계구총인구수        19
# 교차집계구생산인구수       19
# 교차집계구유소년인구수      19
# 교차집계구노년인구수       19
# 인구밀도             19
# 인구밀도지표           15
# 총부양비             15
# 유소년부양비           15
# 노년부양비            15
# 노령화지수            15
# 연령구조지표           15
# dtype: int64

# %% [markdown]
# ###### 거래동향 변수는 결측치 대체가 어려운 것을 판단, drop

# %% [markdown]
# # 전처리 된 데이터 시각화 및 분석

# %%
df_trd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29335 entries, 115 to 385487
# Data columns (total 77 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   아파트코드          29335 non-null  object
#  1   아파트명           29335 non-null  object
#  2   도로명주소          29335 non-null  object
#  3   법정동코드          29335 non-null  int64
#  4   기준년월           29335 non-null  int64
#  5   면적코드           29335 non-null  int64
#  6   거래량            29335 non-null  int64
#  7   누적거래량          29335 non-null  int64
#  8   회전율            29335 non-null  float64
#  9   면적코드별최소실거래가    29335 non-null  int64
#  10  면적코드별최대실거래가    29335 non-null  int64
#  11  면적코드별평균실거래가    29335 non-null  int64
#  12  면적코드별중위실거래가    29335 non-null  int64
#  13  최근거래일자         29335 non-null  int64
#  14  거래동향           20977 non-null  object
#  15  인근아파트거래동향      28288 non-null  object
#  16  해당읍면동거래동향      28698 non-null  object
#  17  기준연도           29335 non-null  int64
#  18  세대수            29250 non-null  float64
#  19  사용승인일자         29195 non-null  float64
#  20  분양유형           20640 non-null  object
#  21  동수             28356 non-null  float64
#  22  복도유형           20637 non-null  object
#  23  시공기업명          20618 non-null  object
#  24  건물구조           27874 non-null  object
#  25  승강기수           28356 non-null  float64
#  26  지상주차대수         20429 non-null  float64
#  27  지하주차대수         20423 non-null  float64
#  28  CCTV수          20423 non-null  float64
#  29  부속복리시설         29335 non-null  object
#  30  학군정보           29320 non-null  object
#  31  교차집계구총인구수      29316 non-null  float64
#  32  교차집계구생산인구수     29316 non-null  float64
#  33  교차집계구유소년인구수    29316 non-null  float64
#  34  교차집계구노년인구수     29316 non-null  float64
#  35  인구밀도           29316 non-null  float64
#  36  인구밀도지표         29320 non-null  float64
#  37  총부양비           29320 non-null  float64
#  38  유소년부양비         29320 non-null  float64
#  39  노년부양비          29320 non-null  float64
#  40  노령화지수          29320 non-null  float64
#  41  연령구조지표         29320 non-null  float64
#  42  지하철역까지_거리      29335 non-null  float64
#  43  지하철역명          29335 non-null  object
#  44  호선             29335 non-null  object
#  45  공원수            29335 non-null  int64
#  46  공원총면적          29335 non-null  float64
#  47  환경생활지수         29335 non-null  int64
#  48  환경평가점수         29335 non-null  int64
#  49  아파트단지내경사도평균값   29335 non-null  float64
#  50  아파트단지내경사도최저값   29335 non-null  float64
#  51  아파트단지내경사도최고값   29335 non-null  float64
#  52  아파트단지인근경사도평균값  29335 non-null  float64
#  53  아파트단지인근경사도최저값  29335 non-null  float64
#  54  아파트단지인근경사도최고값  29335 non-null  float64
#  55  차량접근가능시설수      29335 non-null  int64
#  56  아파트단지내표고평균값    29335 non-null  float64
#  57  아파트단지내표고최저값    29335 non-null  float64
#  58  아파트단지내표고최고값    29335 non-null  float64
#  59  아파트단지인근표고평균값   29335 non-null  float64
#  60  아파트단지인근표고최저값   29335 non-null  float64
#  61  아파트단지인근표고최고값   29335 non-null  float64
#  62  근접 고도 지점 거리    29335 non-null  float64
#  63  cpi            29335 non-null  float64
#  64  경제심리지수(원계열)    29335 non-null  float64
#  65  기존_가계대출        29335 non-null  float64
#  66  신규_가계대출        29335 non-null  float64
#  67  기준금리           29335 non-null  float64
#  68  15_car         29335 non-null  int64
#  69  30_car         29335 non-null  int64
#  70  45_car         29335 non-null  int64
#  71  60_car         29335 non-null  int64
#  72  5_walk         29335 non-null  int64
#  73  10_walk        29335 non-null  int64
#  74  20_walk        29335 non-null  int64
#  75  30_walk        29335 non-null  int64
#  76  자치구명           29335 non-null  object
# dtypes: float64(39), int64(23), object(15)
# memory usage: 17.5+ MB

# %%
df_trd['인근-단지 경사도 평균값'] = df_trd['아파트단지내경사도평균값'] - df_trd['아파트단지인근경사도평균값']
df_trd['인근-단지 경사도 최고값'] = df_trd['아파트단지내경사도최고값'] - df_trd['아파트단지인근경사도최고값']
df_trd['인근-단지 경사도 최저값'] = df_trd['아파트단지내경사도최저값'] - df_trd['아파트단지인근경사도최저값']

df_trd['인근-단지 인근표고 평균값'] = df_trd['아파트단지내표고평균값'] - df_trd['아파트단지인근표고평균값']
df_trd['인근-단지 인근표고 최저값'] = df_trd['아파트단지내표고최저값'] - df_trd['아파트단지인근표고최저값']
df_trd['인근-단지 인근표고 최고값'] = df_trd['아파트단지내표고최고값'] - df_trd['아파트단지인근표고최고값']

df_trd.drop(columns=['아파트단지인근경사도평균값','아파트단지내경사도평균값','아파트단지인근경사도최저값','아파트단지내경사도최저값','아파트단지인근경사도최고값','아파트단지내경사도최고값','아파트단지인근표고최저값','아파트단지내표고최저값','아파트단지인근표고최고값','아파트단지내표고최고값'],inplace=True)

# %%
df_trd.columns
# Out:
# Index(['아파트코드', '아파트명', '도로명주소', '법정동코드', '기준년월', '면적코드', '거래량', '누적거래량',
#        '회전율', '면적코드별최소실거래가', '면적코드별최대실거래가', '면적코드별평균실거래가', '면적코드별중위실거래가',
#        '최근거래일자', '거래동향', '인근아파트거래동향', '해당읍면동거래동향', '기준연도', '세대수', '사용승인일자',
#        '분양유형', '동수', '복도유형', '시공기업명', '건물구조', '승강기수', '지상주차대수', '지하주차대수',
#        'CCTV수', '부속복리시설', '학군정보', '교차집계구총인구수', '교차집계구생산인구수', '교차집계구유소년인구수',
#        '교차집계구노년인구수', '인구밀도', '인구밀도지표', '총부양비', '유소년부양비', '노년부양비', '노령화지수',
#        '연령구조지표', '지하철역까지_거리', '지하철역명', '호선', '공원수', '공원총면적', '환경생활지수',
#        '환경평가점수', '차량접근가능시설수', '아파트단지내표고평균값', '아파트단지인근표고평균값', '근접 고도 지점 거리',
#        'cpi', '경제심리지수(원계열)', '기존_가계대출', '신규_가계대출', '기준금리', '15_car', '30_car',
#        '45_car', '60_car', '5_walk', '10_walk', '20_walk', '30_walk', '자치구명',
#        '인근-단지 경사도 평균값', '인근-단지 경사도 최고값', '인근-단지 경사도 최저값', '인근-단지 인근표고 평균값',
#        '인근-단지 인근표고 최저값', '인근-단지 인근표고 최고값'],
#       dtype='object')

# %%
df_trd.drop(columns=['아파트코드', '아파트명', '도로명주소', '법정동코드', '기준년월', '복도유형', '시공기업명', '건물구조','학군정보','지하철역명','부속복리시설','분양유형','인근아파트거래동향','해당읍면동거래동향','거래동향','면적코드별최소실거래가', '면적코드별최대실거래가','면적코드별중위실거래가',
       '최근거래일자'],inplace=True)

# %%
df_trd.columns
# Out:
# Index(['면적코드', '거래량', '누적거래량', '회전율', '면적코드별평균실거래가', '기준연도', '세대수', '사용승인일자',
#        '동수', '승강기수', '지상주차대수', '지하주차대수', 'CCTV수', '교차집계구총인구수', '교차집계구생산인구수',
#        '교차집계구유소년인구수', '교차집계구노년인구수', '인구밀도', '인구밀도지표', '총부양비', '유소년부양비',
#        '노년부양비', '노령화지수', '연령구조지표', '지하철역까지_거리', '호선', '공원수', '공원총면적', '환경생활지수',
#        '환경평가점수', '차량접근가능시설수', '아파트단지내표고평균값', '아파트단지인근표고평균값', '근접 고도 지점 거리',
#        'cpi', '경제심리지수(원계열)', '기존_가계대출', '신규_가계대출', '기준금리', '15_car', '30_car',
#        '45_car', '60_car', '5_walk', '10_walk', '20_walk', '30_walk', '자치구명',
#        '인근-단지 경사도 평균값', '인근-단지 경사도 최고값', '인근-단지 경사도 최저값', '인근-단지 인근표고 평균값',
#        '인근-단지 인근표고 최저값', '인근-단지 인근표고 최고값'],
#       dtype='object')

# %%
df_trd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29335 entries, 115 to 385487
# Data columns (total 54 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   면적코드            29335 non-null  int64
#  1   거래량             29335 non-null  int64
#  2   누적거래량           29335 non-null  int64
#  3   회전율             29335 non-null  float64
#  4   면적코드별평균실거래가     29335 non-null  int64
#  5   기준연도            29335 non-null  int64
#  6   세대수             29250 non-null  float64
#  7   사용승인일자          29195 non-null  float64
#  8   동수              28356 non-null  float64
#  9   승강기수            28356 non-null  float64
#  10  지상주차대수          20429 non-null  float64
#  11  지하주차대수          20423 non-null  float64
#  12  CCTV수           20423 non-null  float64
#  13  교차집계구총인구수       29316 non-null  float64
#  14  교차집계구생산인구수      29316 non-null  float64
#  15  교차집계구유소년인구수     29316 non-null  float64
#  16  교차집계구노년인구수      29316 non-null  float64
#  17  인구밀도            29316 non-null  float64
#  18  인구밀도지표          29320 non-null  float64
#  19  총부양비            29320 non-null  float64
#  20  유소년부양비          29320 non-null  float64
#  21  노년부양비           29320 non-null  float64
#  22  노령화지수           29320 non-null  float64
#  23  연령구조지표          29320 non-null  float64
#  24  지하철역까지_거리       29335 non-null  float64
#  25  호선              29335 non-null  object
#  26  공원수             29335 non-null  int64
#  27  공원총면적           29335 non-null  float64
#  28  환경생활지수          29335 non-null  int64
#  29  환경평가점수          29335 non-null  int64
#  30  차량접근가능시설수       29335 non-null  int64
#  31  아파트단지내표고평균값     29335 non-null  float64
#  32  아파트단지인근표고평균값    29335 non-null  float64
#  33  근접 고도 지점 거리     29335 non-null  float64
#  34  cpi             29335 non-null  float64
#  35  경제심리지수(원계열)     29335 non-null  float64
#  36  기존_가계대출         29335 non-null  float64
#  37  신규_가계대출         29335 non-null  float64
#  38  기준금리            29335 non-null  float64
#  39  15_car          29335 non-null  int64
#  40  30_car          29335 non-null  int64
#  41  45_car          29335 non-null  int64
#  42  60_car          29335 non-null  int64
#  43  5_walk          29335 non-null  int64
#  44  10_walk         29335 non-null  int64
#  45  20_walk         29335 non-null  int64
#  46  30_walk         29335 non-null  int64
#  47  자치구명            29335 non-null  object
#  48  인근-단지 경사도 평균값   29335 non-null  float64
#  49  인근-단지 경사도 최고값   29335 non-null  float64
#  50  인근-단지 경사도 최저값   29335 non-null  float64
#  51  인근-단지 인근표고 평균값  29335 non-null  float64
#  52  인근-단지 인근표고 최저값  29335 non-null  float64
#  53  인근-단지 인근표고 최고값  29335 non-null  float64
# dtypes: float64(35), int64(17), object(2)
# memory usage: 12.3+ MB

# %%
for i in df_trd.columns:
    print("{}의 결측치 비율 : {}".format(i,pd.isna(df_trd[i]).sum()/len(df_trd)))
# Out:
# 면적코드의 결측치 비율 : 0.0
# 거래량의 결측치 비율 : 0.0
# 누적거래량의 결측치 비율 : 0.0
# 회전율의 결측치 비율 : 0.0
# 면적코드별평균실거래가의 결측치 비율 : 0.0
# 기준연도의 결측치 비율 : 0.0
# 세대수의 결측치 비율 : 0.0028975626384864497
# 사용승인일자의 결측치 비율 : 0.00477245611044827
# 동수의 결측치 비율 : 0.0333731038009204
# 승강기수의 결측치 비율 : 0.0333731038009204
# 지상주차대수의 결측치 비율 : 0.30359638656894494
# 지하주차대수의 결측치 비율 : 0.3038009204022499
# CCTV수의 결측치 비율 : 0.3038009204022499
# 교차집계구총인구수의 결측치 비율 : 0.0006476904721322652
# 교차집계구생산인구수의 결측치 비율 : 0.0006476904721322652
# 교차집계구유소년인구수의 결측치 비율 : 0.0006476904721322652
# 교차집계구노년인구수의 결측치 비율 : 0.0006476904721322652
# 인구밀도의 결측치 비율 : 0.0006476904721322652
# 인구밀도지표의 결측치 비율 : 0.0005113345832623146
# 총부양비의 결측치 비율 : 0.0005113345832623146
# 유소년부양비의 결측치 비율 : 0.0005113345832623146
# 노년부양비의 결측치 비율 : 0.0005113345832623146
# 노령화지수의 결측치 비율 : 0.0005113345832623146
# 연령구조지표의 결측치 비율 : 0.0005113345832623146
# 지하철역까지_거리의 결측치 비율 : 0.0
# 호선의 결측치 비율 : 0.0
# 공원수의 결측치 비율 : 0.0
# 공원총면적의 결측치 비율 : 0.0
# 환경생활지수의 결측치 비율 : 0.0
# 환경평가점수의 결측치 비율 : 0.0
# 차량접근가능시설수의 결측치 비율 : 0.0
# 아파트단지내표고평균값의 결측치 비율 : 0.0
# 아파트단지인근표고평균값의 결측치 비율 : 0.0
# 근접 고도 지점 거리의 결측치 비율 : 0.0
# cpi의 결측치 비율 : 0.0
# 경제심리지수(원계열)의 결측치 비율 : 0.0
# 기존_가계대출의 결측치 비율 : 0.0
# 신규_가계대출의 결측치 비율 : 0.0
# 기준금리의 결측치 비율 : 0.0
# 15_car의 결측치 비율 : 0.0
# 30_car의 결측치 비율 : 0.0
# 45_car의 결측치 비율 : 0.0
# 60_car의 결측치 비율 : 0.0
# 5_walk의 결측치 비율 : 0.0
# 10_walk의 결측치 비율 : 0.0
# 20_walk의 결측치 비율 : 0.0
# 30_walk의 결측치 비율 : 0.0
# 자치구명의 결측치 비율 : 0.0
# 인근-단지 경사도 평균값의 결측치 비율 : 0.0
# 인근-단지 경사도 최고값의 결측치 비율 : 0.0
# 인근-단지 경사도 최저값의 결측치 비율 : 0.0
# 인근-단지 인근표고 평균값의 결측치 비율 : 0.0
# 인근-단지 인근표고 최저값의 결측치 비율 : 0.0
# 인근-단지 인근표고 최고값의 결측치 비율 : 0.0

# %%
for i in df_trd.columns:
    if pd.isna(df_trd[i]).sum()/len(df_trd) > 0.1:
        df_trd.drop(columns=i,inplace=True)

# %%
for i in df_trd.columns:
    print("{}의 결측치 비율 : {}".format(i,pd.isna(df_trd[i]).sum()/len(df_trd)))
# Out:
# 면적코드의 결측치 비율 : 0.0
# 거래량의 결측치 비율 : 0.0
# 누적거래량의 결측치 비율 : 0.0
# 회전율의 결측치 비율 : 0.0
# 면적코드별평균실거래가의 결측치 비율 : 0.0
# 기준연도의 결측치 비율 : 0.0
# 세대수의 결측치 비율 : 0.0028975626384864497
# 사용승인일자의 결측치 비율 : 0.00477245611044827
# 동수의 결측치 비율 : 0.0333731038009204
# 승강기수의 결측치 비율 : 0.0333731038009204
# 교차집계구총인구수의 결측치 비율 : 0.0006476904721322652
# 교차집계구생산인구수의 결측치 비율 : 0.0006476904721322652
# 교차집계구유소년인구수의 결측치 비율 : 0.0006476904721322652
# 교차집계구노년인구수의 결측치 비율 : 0.0006476904721322652
# 인구밀도의 결측치 비율 : 0.0006476904721322652
# 인구밀도지표의 결측치 비율 : 0.0005113345832623146
# 총부양비의 결측치 비율 : 0.0005113345832623146
# 유소년부양비의 결측치 비율 : 0.0005113345832623146
# 노년부양비의 결측치 비율 : 0.0005113345832623146
# 노령화지수의 결측치 비율 : 0.0005113345832623146
# 연령구조지표의 결측치 비율 : 0.0005113345832623146
# 지하철역까지_거리의 결측치 비율 : 0.0
# 호선의 결측치 비율 : 0.0
# 공원수의 결측치 비율 : 0.0
# 공원총면적의 결측치 비율 : 0.0
# 환경생활지수의 결측치 비율 : 0.0
# 환경평가점수의 결측치 비율 : 0.0
# 차량접근가능시설수의 결측치 비율 : 0.0
# 아파트단지내표고평균값의 결측치 비율 : 0.0
# 아파트단지인근표고평균값의 결측치 비율 : 0.0
# 근접 고도 지점 거리의 결측치 비율 : 0.0
# cpi의 결측치 비율 : 0.0
# 경제심리지수(원계열)의 결측치 비율 : 0.0
# 기존_가계대출의 결측치 비율 : 0.0
# 신규_가계대출의 결측치 비율 : 0.0
# 기준금리의 결측치 비율 : 0.0
# 15_car의 결측치 비율 : 0.0
# 30_car의 결측치 비율 : 0.0
# 45_car의 결측치 비율 : 0.0
# 60_car의 결측치 비율 : 0.0
# 5_walk의 결측치 비율 : 0.0
# 10_walk의 결측치 비율 : 0.0
# 20_walk의 결측치 비율 : 0.0
# 30_walk의 결측치 비율 : 0.0
# 자치구명의 결측치 비율 : 0.0
# 인근-단지 경사도 평균값의 결측치 비율 : 0.0
# 인근-단지 경사도 최고값의 결측치 비율 : 0.0
# 인근-단지 경사도 최저값의 결측치 비율 : 0.0
# 인근-단지 인근표고 평균값의 결측치 비율 : 0.0
# 인근-단지 인근표고 최저값의 결측치 비율 : 0.0
# 인근-단지 인근표고 최고값의 결측치 비율 : 0.0

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False


sns.histplot(df_trd['면적코드별평균실거래가'], bins=50)
# Out:
# <Axes: xlabel='면적코드별평균실거래가', ylabel='Count'>

# %%
df_trd['target'] = df_trd['면적코드별평균실거래가']
df_trd.drop(columns=['면적코드별평균실거래가'],inplace=True)

# %%
plt.figure(figsize=(30,30))
sns.heatmap(df_trd.loc[:,df_trd.select_dtypes(include=['int64','float64']).columns].corr(),annot=True, cmap='coolwarm', fmt='.1f')
plt.show()

# %%
df_trd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29335 entries, 115 to 385487
# Data columns (total 51 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   면적코드            29335 non-null  int64
#  1   거래량             29335 non-null  int64
#  2   누적거래량           29335 non-null  int64
#  3   회전율             29335 non-null  float64
#  4   기준연도            29335 non-null  int64
#  5   세대수             29250 non-null  float64
#  6   사용승인일자          29195 non-null  float64
#  7   동수              28356 non-null  float64
#  8   승강기수            28356 non-null  float64
#  9   교차집계구총인구수       29316 non-null  float64
#  10  교차집계구생산인구수      29316 non-null  float64
#  11  교차집계구유소년인구수     29316 non-null  float64
#  12  교차집계구노년인구수      29316 non-null  float64
#  13  인구밀도            29316 non-null  float64
#  14  인구밀도지표          29320 non-null  float64
#  15  총부양비            29320 non-null  float64
#  16  유소년부양비          29320 non-null  float64
#  17  노년부양비           29320 non-null  float64
#  18  노령화지수           29320 non-null  float64
#  19  연령구조지표          29320 non-null  float64
#  20  지하철역까지_거리       29335 non-null  float64
#  21  호선              29335 non-null  object
#  22  공원수             29335 non-null  int64
#  23  공원총면적           29335 non-null  float64
#  24  환경생활지수          29335 non-null  int64
#  25  환경평가점수          29335 non-null  int64
#  26  차량접근가능시설수       29335 non-null  int64
#  27  아파트단지내표고평균값     29335 non-null  float64
#  28  아파트단지인근표고평균값    29335 non-null  float64
#  29  근접 고도 지점 거리     29335 non-null  float64
#  30  cpi             29335 non-null  float64
#  31  경제심리지수(원계열)     29335 non-null  float64
#  32  기존_가계대출         29335 non-null  float64
#  33  신규_가계대출         29335 non-null  float64
#  34  기준금리            29335 non-null  float64
#  35  15_car          29335 non-null  int64
#  36  30_car          29335 non-null  int64
#  37  45_car          29335 non-null  int64
#  38  60_car          29335 non-null  int64
#  39  5_walk          29335 non-null  int64
#  40  10_walk         29335 non-null  int64
#  41  20_walk         29335 non-null  int64
#  42  30_walk         29335 non-null  int64
#  43  자치구명            29335 non-null  object
#  44  인근-단지 경사도 평균값   29335 non-null  float64
#  45  인근-단지 경사도 최고값   29335 non-null  float64
#  46  인근-단지 경사도 최저값   29335 non-null  float64
#  47  인근-단지 인근표고 평균값  29335 non-null  float64
#  48  인근-단지 인근표고 최저값  29335 non-null  float64
#  49  인근-단지 인근표고 최고값  29335 non-null  float64
#  50  target          29335 non-null  int64
# dtypes: float64(32), int64(17), object(2)
# memory usage: 11.6+ MB

# %%
df_trd = pd.get_dummies(df_trd, columns=['호선'], prefix='호선').copy()
target_feature = 'target'

# target feature를 맨 뒤로 이동
columns = [col for col in df_trd.columns if col != target_feature] + [target_feature]
df_trd = df_trd[columns]

# %%
df_trd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29335 entries, 115 to 385487
# Data columns (total 75 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   면적코드            29335 non-null  int64
#  1   거래량             29335 non-null  int64
#  2   누적거래량           29335 non-null  int64
#  3   회전율             29335 non-null  float64
#  4   기준연도            29335 non-null  int64
#  5   세대수             29250 non-null  float64
#  6   사용승인일자          29195 non-null  float64
#  7   동수              28356 non-null  float64
#  8   승강기수            28356 non-null  float64
#  9   교차집계구총인구수       29316 non-null  float64
#  10  교차집계구생산인구수      29316 non-null  float64
#  11  교차집계구유소년인구수     29316 non-null  float64
#  12  교차집계구노년인구수      29316 non-null  float64
#  13  인구밀도            29316 non-null  float64
#  14  인구밀도지표          29320 non-null  float64
#  15  총부양비            29320 non-null  float64
#  16  유소년부양비          29320 non-null  float64
#  17  노년부양비           29320 non-null  float64
#  18  노령화지수           29320 non-null  float64
#  19  연령구조지표          29320 non-null  float64
#  20  지하철역까지_거리       29335 non-null  float64
#  21  공원수             29335 non-null  int64
#  22  공원총면적           29335 non-null  float64
#  23  환경생활지수          29335 non-null  int64
#  24  환경평가점수          29335 non-null  int64
#  25  차량접근가능시설수       29335 non-null  int64
#  26  아파트단지내표고평균값     29335 non-null  float64
#  27  아파트단지인근표고평균값    29335 non-null  float64
#  28  근접 고도 지점 거리     29335 non-null  float64
#  29  cpi             29335 non-null  float64
#  30  경제심리지수(원계열)     29335 non-null  float64
#  31  기존_가계대출         29335 non-null  float64
#  32  신규_가계대출         29335 non-null  float64
#  33  기준금리            29335 non-null  float64
#  34  15_car          29335 non-null  int64
#  35  30_car          29335 non-null  int64
#  36  45_car          29335 non-null  int64
#  37  60_car          29335 non-null  int64
#  38  5_walk          29335 non-null  int64
#  39  10_walk         29335 non-null  int64
#  40  20_walk         29335 non-null  int64
#  41  30_walk         29335 non-null  int64
#  42  자치구명            29335 non-null  object
#  43  인근-단지 경사도 평균값   29335 non-null  float64
#  44  인근-단지 경사도 최고값   29335 non-null  float64
#  45  인근-단지 경사도 최저값   29335 non-null  float64
#  46  인근-단지 인근표고 평균값  29335 non-null  float64
#  47  인근-단지 인근표고 최저값  29335 non-null  float64
#  48  인근-단지 인근표고 최고값  29335 non-null  float64
#  49  호선_1호선          29335 non-null  uint8
#  50  호선_2호선          29335 non-null  uint8
#  51  호선_3호선          29335 non-null  uint8
#  52  호선_4호선          29335 non-null  uint8
#  53  호선_5호선          29335 non-null  uint8
#  54  호선_6호선          29335 non-null  uint8
#  55  호선_7호선          29335 non-null  uint8
#  56  호선_8호선          29335 non-null  uint8
#  57  호선_9호선          29335 non-null  uint8
#  58  호선_9호선(연장)      29335 non-null  uint8
#  59  호선_경부선          29335 non-null  uint8
#  60  호선_경원선          29335 non-null  uint8
#  61  호선_경의중앙선        29335 non-null  uint8
#  62  호선_경인선          29335 non-null  uint8
#  63  호선_경춘선          29335 non-null  uint8
#  64  호선_공항철도1호선      29335 non-null  uint8
#  65  호선_과천선          29335 non-null  uint8
#  66  호선_분당선          29335 non-null  uint8
#  67  호선_수도권 광역급행철도   29335 non-null  uint8
#  68  호선_신림선          29335 non-null  uint8
#  69  호선_신분당선         29335 non-null  uint8
#  70  호선_신분당선(연장2)    29335 non-null  uint8
#  71  호선_우이신설선        29335 non-null  uint8
#  72  호선_일산선          29335 non-null  uint8
#  73  호선_중앙선          29335 non-null  uint8
#  74  target          29335 non-null  int64
# dtypes: float64(32), int64(17), object(1), uint8(25)
# memory usage: 12.1+ MB

# %%
df= df_trd.copy()

# %%
import os
import sys
sys.path.append("../../../../../../mnt/workspace/LightGBM/python-package")
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
import warnings
warnings.filterwarnings(action='ignore')

X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2, random_state=42, stratify=df.loc[:,'자치구명']) # train, test set 분리
X_tr, X_val, Y_tr, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42, stratify=X_train['자치구명']) # train, validation set 분리

X_tr.drop(columns='자치구명',inplace=True) # 자치구명 제거
X_val.drop(columns='자치구명',inplace=True) # 자치구명 제거


# 모델 학습
# XGBoost 분류기 초기화
xgb_model= XGBRegressor(
                    tree_method= 'hist',
                    device='cuda',
                    n_estimators= 4000,
                    random_state= 42,
                    enable_categorical= True,
                    early_stopping_rounds= 200
                )

xgb_model.fit(X_tr, Y_tr, eval_set=[(X_val, Y_val)], verbose= False)

# 기본 성능 평가
baseline_score = mean_squared_error(Y_test, xgb_model.predict(X_test.drop(columns='자치구명')), squared=False)
print(f'Baseline Score: {baseline_score:.4f}')


# Permutation Importance 평가
perm_importance = permutation_importance(xgb_model, X_val, Y_val, n_repeats=20, random_state=42, scoring='neg_root_mean_squared_error', n_jobs=-1)

# 변수 중요도 출력
for i in perm_importance.importances_mean.argsort()[::-1]:
    print(f"Feature {X_tr.columns[i]}, Importance: {perm_importance.importances_mean[i]:.4f} ± {perm_importance.importances_std[i]:.4f}")
# Out:
# Baseline Score: 241586632.5080
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:04] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:04] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:04] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:04] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:04] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:04] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:04] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:04] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:04] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# /usr/local/lib/python3.8/dist-packages/xgboost/core.py:160: UserWarning: [11:26:05] WARNING: /workspace/src/common/error_msg.cc:58: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   warnings.warn(smsg, UserWarning)
# Feature 면적코드, Importance: 422082287.8187 ± 10728860.0753
# Feature 15_car, Importance: 323527837.2686 ± 14613532.9983
# Feature 사용승인일자, Importance: 77104391.1129 ± 4982055.7116
# Feature 승강기수, Importance: 76311787.6535 ± 10036444.1342
# Feature 차량접근가능시설수, Importance: 74944899.0616 ± 3596281.0744
# Feature 유소년부양비, Importance: 56543172.4414 ± 3272890.5506
# Feature 30_car, Importance: 53618306.3957 ± 1795372.5201
# Feature 30_walk, Importance: 45371814.0567 ± 1490752.1199
# Feature 인구밀도, Importance: 40839937.9575 ± 2637842.5038
# Feature 45_car, Importance: 37106247.4657 ± 2405581.7663
# Feature 호선_분당선, Importance: 35898855.9100 ± 2601279.2318
# Feature 인근-단지 인근표고 최저값, Importance: 28929396.7689 ± 3376929.5657
# Feature 세대수, Importance: 26739145.5222 ± 1397621.9776
# Feature 동수, Importance: 25927809.7668 ± 1487328.7622
# Feature 지하철역까지_거리, Importance: 25305891.9229 ± 1966999.6729
# Feature 교차집계구유소년인구수, Importance: 24770380.6374 ± 1350389.3402
# Feature 호선_3호선, Importance: 22247982.8173 ± 1313991.5640
# Feature 근접 고도 지점 거리, Importance: 20863272.6428 ± 2663042.4708
# Feature 5_walk, Importance: 18494940.6616 ± 1595364.9471
# Feature 20_walk, Importance: 17401923.0176 ± 1610562.8110
# Feature 아파트단지내표고평균값, Importance: 16287160.4059 ± 2445232.0918
# Feature 공원총면적, Importance: 15939335.2880 ± 1352811.2853
# Feature 노령화지수, Importance: 14414770.3633 ± 898852.6755
# Feature 누적거래량, Importance: 11600598.9614 ± 2725256.0639
# Feature 인근-단지 경사도 최고값, Importance: 11449875.7793 ± 1171673.1718
# Feature 10_walk, Importance: 10549506.5177 ± 897798.0213
# Feature 아파트단지인근표고평균값, Importance: 10314277.0725 ± 1024743.4330
# Feature 인근-단지 인근표고 최고값, Importance: 8256385.6231 ± 1000198.8105
# Feature 인근-단지 인근표고 평균값, Importance: 7928535.2981 ± 1345380.9467
# Feature 회전율, Importance: 7242840.9124 ± 941014.8621
# Feature 총부양비, Importance: 7204985.3283 ± 1459114.9141
# Feature 교차집계구총인구수, Importance: 5615415.5761 ± 1369636.2568
# Feature cpi, Importance: 5167434.3565 ± 1313541.1034
# Feature 호선_9호선(연장), Importance: 4215628.2742 ± 411929.1730
# Feature 인근-단지 경사도 평균값, Importance: 4152099.4536 ± 699299.7672
# Feature 노년부양비, Importance: 4106343.8534 ± 617077.6683
# Feature 기존_가계대출, Importance: 3785489.8144 ± 1615607.4385
# Feature 교차집계구생산인구수, Importance: 3781005.9344 ± 988439.0766
# Feature 호선_2호선, Importance: 2959719.1850 ± 367583.2146
# Feature 경제심리지수(원계열), Importance: 2892554.7158 ± 1274815.1481
# Feature 공원수, Importance: 2666963.9074 ± 1146790.4153
# Feature 호선_4호선, Importance: 2604404.7849 ± 467339.8636
# Feature 호선_7호선, Importance: 2004506.3805 ± 633317.1685
# Feature 신규_가계대출, Importance: 1989558.8077 ± 1130412.9235
# Feature 호선_경인선, Importance: 1793347.4072 ± 276933.3487
# Feature 호선_5호선, Importance: 1785672.5858 ± 164456.0126
# Feature 호선_8호선, Importance: 1434837.0801 ± 422780.4203
# Feature 환경평가점수, Importance: 1402432.6112 ± 234747.1741
# Feature 거래량, Importance: 1108079.2979 ± 785142.2732
# Feature 호선_6호선, Importance: 761459.2496 ± 393189.7569
# Feature 호선_수도권 광역급행철도, Importance: 723498.5740 ± 150949.8580
# Feature 호선_중앙선, Importance: 704972.5744 ± 283294.9350
# Feature 호선_경원선, Importance: 509230.8077 ± 186501.6590
# Feature 호선_신분당선, Importance: 472679.1211 ± 106116.6482
# Feature 교차집계구노년인구수, Importance: 442493.9333 ± 867398.5953
# Feature 연령구조지표, Importance: 412795.3513 ± 211215.8248
# Feature 호선_9호선, Importance: 391666.7853 ± 340854.5876
# Feature 호선_우이신설선, Importance: 329311.5204 ± 121242.4574
# Feature 호선_경춘선, Importance: 227266.6035 ± 60194.3188
# Feature 호선_경부선, Importance: 92374.5566 ± 39960.7251
# Feature 인근-단지 경사도 최저값, Importance: 78328.6071 ± 155792.9174
# Feature 인구밀도지표, Importance: 74447.3562 ± 30198.7805
# Feature 호선_공항철도1호선, Importance: 64158.8994 ± 43424.8412
# Feature 호선_경의중앙선, Importance: 60357.3552 ± 70189.3703
# Feature 호선_1호선, Importance: 27857.0578 ± 10919.7793
# Feature 호선_신분당선(연장2), Importance: 9481.3827 ± 17008.1104
# Feature 60_car, Importance: 0.0000 ± 0.0000
# Feature 기준금리, Importance: 0.0000 ± 0.0000
# Feature 환경생활지수, Importance: 0.0000 ± 0.0000
# Feature 호선_일산선, Importance: -939.8076 ± 9236.8109
# Feature 호선_과천선, Importance: -1482.2728 ± 10124.4664
# Feature 호선_신림선, Importance: -23637.9633 ± 53459.7900
# Feature 기준연도, Importance: -209011.8717 ± 167902.4694

# %%
df.drop(columns='기준연도', inplace=True)

# %%
import os
import sys
sys.path.append("../../../../../../mnt/workspace/LightGBM/python-package")
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
import warnings
warnings.filterwarnings(action='ignore')

X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2, random_state=42, stratify=df.loc[:,'자치구명']) # train, test set 분리
X_tr, X_val, Y_tr, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42, stratify=X_train['자치구명']) # train, validation set 분리

X_tr.drop(columns='자치구명',inplace=True) # 자치구명 제거
X_val.drop(columns='자치구명',inplace=True) # 자치구명 제거


# 모델 학습
# XGBoost 분류기 초기화
xgb_model= XGBRegressor(
                    tree_method= 'hist',
                    device='cuda',
                    n_estimators= 4000,
                    random_state= 42,
                    enable_categorical= True,
                    early_stopping_rounds= 200
                )

xgb_model.fit(X_tr, Y_tr, eval_set=[(X_val, Y_val)], verbose= False)

# 기본 성능 평가
baseline_score = mean_squared_error(Y_test, xgb_model.predict(X_test.drop(columns='자치구명')), squared=False)
print(f'Baseline Score: {baseline_score:.4f}')


# Permutation Importance 평가
perm_importance = permutation_importance(xgb_model, X_val, Y_val, n_repeats=20, random_state=42, scoring='neg_root_mean_squared_error', n_jobs=-1)

# 변수 중요도 출력
for i in perm_importance.importances_mean.argsort()[::-1]:
    print(f"Feature {X_tr.columns[i]}, Importance: {perm_importance.importances_mean[i]:.4f} ± {perm_importance.importances_std[i]:.4f}")
# Out:
# Baseline Score: 240894172.1702
# Feature 면적코드, Importance: 426101613.5495 ± 11163865.8857
# Feature 15_car, Importance: 313211496.4455 ± 14611780.0547
# Feature 사용승인일자, Importance: 83890016.1150 ± 5205405.6698
# Feature 차량접근가능시설수, Importance: 81377265.9827 ± 4673312.5942
# Feature 승강기수, Importance: 79028713.6612 ± 9627327.8791
# Feature 30_car, Importance: 61393526.9512 ± 2413564.1521
# Feature 유소년부양비, Importance: 61139489.4129 ± 3207618.5316
# Feature 30_walk, Importance: 41453925.8725 ± 1669489.6514
# Feature 인구밀도, Importance: 40920498.8915 ± 2499783.9152
# Feature 호선_분당선, Importance: 33607408.0017 ± 2360135.5212
# Feature 세대수, Importance: 31833813.1637 ± 1652750.1689
# Feature 인근-단지 인근표고 최저값, Importance: 31773797.6311 ± 3761679.7541
# Feature 동수, Importance: 26703573.1458 ± 1418927.3147
# Feature 호선_3호선, Importance: 26265002.3002 ± 1519995.8407
# Feature 지하철역까지_거리, Importance: 25001529.2058 ± 2359911.5431
# Feature 45_car, Importance: 24101816.9186 ± 2076838.6793
# Feature 교차집계구유소년인구수, Importance: 23182143.6966 ± 1625672.8875
# Feature 근접 고도 지점 거리, Importance: 20678760.6322 ± 2770248.2437
# Feature 20_walk, Importance: 20065052.6045 ± 1560655.6685
# Feature 5_walk, Importance: 17260977.0822 ± 1600859.2883
# Feature 노령화지수, Importance: 17053190.2310 ± 1877441.4048
# Feature 공원총면적, Importance: 16304092.3075 ± 1511959.8895
# Feature 누적거래량, Importance: 14588279.7415 ± 2308578.8418
# Feature 아파트단지내표고평균값, Importance: 11882839.9321 ± 2773295.1948
# Feature 인근-단지 경사도 최고값, Importance: 11124307.0073 ± 1092180.0879
# Feature 회전율, Importance: 8083850.0282 ± 834870.2003
# Feature 아파트단지인근표고평균값, Importance: 7828428.5541 ± 1249143.0853
# Feature 인근-단지 인근표고 평균값, Importance: 7789962.0650 ± 1447468.5365
# Feature 총부양비, Importance: 7627145.8285 ± 1230244.9732
# Feature 인근-단지 인근표고 최고값, Importance: 7610095.6594 ± 933808.7297
# Feature 10_walk, Importance: 7284209.1671 ± 656269.8169
# Feature cpi, Importance: 6937654.8623 ± 1627299.2415
# Feature 기존_가계대출, Importance: 6788361.9766 ± 1707106.5020
# Feature 교차집계구생산인구수, Importance: 5826990.0417 ± 734579.8943
# Feature 교차집계구총인구수, Importance: 5445287.0763 ± 1233993.7707
# Feature 호선_9호선(연장), Importance: 5003979.0737 ± 327463.1267
# Feature 인근-단지 경사도 평균값, Importance: 4223440.5347 ± 714575.3981
# Feature 호선_4호선, Importance: 3181115.9891 ± 591140.6621
# Feature 경제심리지수(원계열), Importance: 2951360.6633 ± 1777874.1165
# Feature 호선_5호선, Importance: 2789203.8877 ± 254349.8466
# Feature 공원수, Importance: 2691155.3595 ± 1244515.8600
# Feature 호선_2호선, Importance: 2384440.0644 ± 354536.2835
# Feature 호선_7호선, Importance: 2065276.8066 ± 804462.5310
# Feature 교차집계구노년인구수, Importance: 1580139.5232 ± 1087668.0545
# Feature 노년부양비, Importance: 1523128.8792 ± 699709.9885
# Feature 호선_경인선, Importance: 1521461.0189 ± 285371.7764
# Feature 호선_8호선, Importance: 1211349.1050 ± 206869.5873
# Feature 호선_신분당선, Importance: 1121058.1290 ± 155725.4579
# Feature 호선_수도권 광역급행철도, Importance: 635967.7635 ± 158269.8364
# Feature 호선_중앙선, Importance: 603400.0039 ± 170594.3227
# Feature 환경평가점수, Importance: 576414.8095 ± 243223.5504
# Feature 호선_경부선, Importance: 501640.7914 ± 214668.8199
# Feature 연령구조지표, Importance: 499173.7226 ± 217286.2126
# Feature 호선_6호선, Importance: 465550.0487 ± 210538.3490
# Feature 호선_우이신설선, Importance: 394144.6803 ± 146053.0259
# Feature 호선_9호선, Importance: 330991.3835 ± 268594.8515
# Feature 호선_경원선, Importance: 320248.2395 ± 213777.4728
# Feature 인근-단지 경사도 최저값, Importance: 243534.7852 ± 241758.3133
# Feature 신규_가계대출, Importance: 227031.2134 ± 1031419.1616
# Feature 호선_경춘선, Importance: 88642.8419 ± 16671.2600
# Feature 호선_경의중앙선, Importance: 74420.0159 ± 78015.4067
# Feature 호선_공항철도1호선, Importance: 54490.5953 ± 33082.2005
# Feature 호선_1호선, Importance: 32770.7909 ± 38054.7633
# Feature 기준금리, Importance: 0.0000 ± 0.0000
# Feature 호선_신분당선(연장2), Importance: -6620.2505 ± 15007.8972
# Feature 인구밀도지표, Importance: -59810.8388 ± 39361.2153

# %%
df.drop(columns='인구밀도지표', inplace=True)

# %%
import os
import sys
sys.path.append("../../../../../../mnt/workspace/LightGBM/python-package")
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
import warnings
warnings.filterwarnings(action='ignore')

X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2, random_state=42, stratify=df.loc[:,'자치구명']) # train, test set 분리
X_tr, X_val, Y_tr, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42, stratify=X_train['자치구명']) # train, validation set 분리

X_tr.drop(columns='자치구명',inplace=True) # 자치구명 제거
X_val.drop(columns='자치구명',inplace=True) # 자치구명 제거


# 모델 학습
# XGBoost 분류기 초기화
xgb_model= XGBRegressor(
                    tree_method= 'hist',
                    device='cuda',
                    n_estimators= 4000,
                    random_state= 42,
                    enable_categorical= True,
                    early_stopping_rounds= 200
                )

xgb_model.fit(X_tr, Y_tr, eval_set=[(X_val, Y_val)], verbose= False)

# 기본 성능 평가
baseline_score = mean_squared_error(Y_test, xgb_model.predict(X_test.drop(columns='자치구명')), squared=False)
print(f'Baseline Score: {baseline_score:.4f}')


# Permutation Importance 평가
perm_importance = permutation_importance(xgb_model, X_val, Y_val, n_repeats=20, random_state=42, scoring='neg_root_mean_squared_error', n_jobs=-1)

# 변수 중요도 출력
for i in perm_importance.importances_mean.argsort()[::-1]:
    print(f"Feature {X_tr.columns[i]}, Importance: {perm_importance.importances_mean[i]:.4f} ± {perm_importance.importances_std[i]:.4f}")
# Out:
# Baseline Score: 243176529.4427
# Feature 면적코드, Importance: 423486748.3441 ± 11072056.7211
# Feature 15_car, Importance: 316749795.8973 ± 14348592.4284
# Feature 차량접근가능시설수, Importance: 101540281.6639 ± 4718897.7608
# Feature 사용승인일자, Importance: 82736708.0117 ± 5061357.4225
# Feature 승강기수, Importance: 79351659.7782 ± 9722700.8482
# Feature 유소년부양비, Importance: 61922364.7411 ± 3208282.5294
# Feature 30_car, Importance: 61539346.6912 ± 2698745.6680
# Feature 30_walk, Importance: 40343368.4654 ± 1807605.2306
# Feature 인구밀도, Importance: 40260756.2102 ± 2569467.7839
# Feature 호선_분당선, Importance: 33055219.7025 ± 2189384.1861
# Feature 인근-단지 인근표고 최저값, Importance: 31350175.7849 ± 3723658.8447
# Feature 세대수, Importance: 29683905.5244 ± 1625386.6834
# Feature 동수, Importance: 28140286.9244 ± 1308384.6119
# Feature 호선_3호선, Importance: 25774918.7004 ± 1400946.0382
# Feature 지하철역까지_거리, Importance: 25453428.4719 ± 2300918.3391
# Feature 45_car, Importance: 25237765.4105 ± 2358683.3713
# Feature 교차집계구유소년인구수, Importance: 22393471.4819 ± 1765052.2118
# Feature 20_walk, Importance: 21837089.6539 ± 1677902.3174
# Feature 근접 고도 지점 거리, Importance: 19592676.4994 ± 2758394.3147
# Feature 5_walk, Importance: 16887197.4858 ± 1601439.7276
# Feature 공원총면적, Importance: 15993774.9319 ± 1497827.5025
# Feature 노령화지수, Importance: 15727717.9778 ± 1848669.8223
# Feature 아파트단지내표고평균값, Importance: 13501665.8058 ± 2789155.2706
# Feature 누적거래량, Importance: 12896350.3549 ± 2264604.2296
# Feature 인근-단지 경사도 최고값, Importance: 10854207.5408 ± 1009881.8060
# Feature 회전율, Importance: 9621818.4064 ± 878248.7201
# Feature 아파트단지인근표고평균값, Importance: 8136068.4785 ± 1354451.1909
# Feature 10_walk, Importance: 7701931.9626 ± 776924.3661
# Feature 인근-단지 인근표고 평균값, Importance: 7168404.9193 ± 1433153.5311
# Feature 총부양비, Importance: 7142066.4849 ± 1107923.9130
# Feature 인근-단지 인근표고 최고값, Importance: 6672636.3044 ± 1070727.6536
# Feature 기존_가계대출, Importance: 6576659.0089 ± 1745378.8113
# Feature cpi, Importance: 6447684.2738 ± 1548224.0761
# Feature 교차집계구총인구수, Importance: 6007415.0381 ± 1233221.6392
# Feature 호선_9호선(연장), Importance: 4792205.5849 ± 266387.1835
# Feature 인근-단지 경사도 평균값, Importance: 3663875.9540 ± 702183.7080
# Feature 호선_4호선, Importance: 3581052.4764 ± 593027.1499
# Feature 교차집계구생산인구수, Importance: 3291410.8674 ± 692417.0308
# Feature 호선_5호선, Importance: 3022565.5224 ± 263881.1844
# Feature 공원수, Importance: 2721171.1142 ± 1258948.9441
# Feature 교차집계구노년인구수, Importance: 2643156.5311 ± 897547.2366
# Feature 호선_2호선, Importance: 2594563.7184 ± 386046.2869
# Feature 호선_7호선, Importance: 2157534.3538 ± 813822.8786
# Feature 경제심리지수(원계열), Importance: 1625765.9551 ± 1826147.5259
# Feature 호선_경인선, Importance: 1352165.6984 ± 231114.6985
# Feature 호선_8호선, Importance: 1186425.5965 ± 234883.9158
# Feature 호선_신분당선, Importance: 1173193.4309 ± 210863.9482
# Feature 노년부양비, Importance: 1104380.7707 ± 662040.1573
# Feature 호선_수도권 광역급행철도, Importance: 635000.7964 ± 171645.7917
# Feature 호선_중앙선, Importance: 610946.6088 ± 163925.7813
# Feature 호선_경원선, Importance: 530240.1437 ± 247505.1528
# Feature 호선_6호선, Importance: 505548.5407 ± 218940.7230
# Feature 호선_경부선, Importance: 500473.3315 ± 230933.2824
# Feature 환경평가점수, Importance: 453283.4957 ± 207061.7830
# Feature 호선_우이신설선, Importance: 385981.3288 ± 148222.4003
# Feature 호선_9호선, Importance: 316645.7167 ± 240650.2415
# Feature 인근-단지 경사도 최저값, Importance: 301525.3894 ± 227352.6914
# Feature 연령구조지표, Importance: 111721.1638 ± 253876.7597
# Feature 호선_경의중앙선, Importance: 99861.9906 ± 58330.5001
# Feature 호선_경춘선, Importance: 72561.1523 ± 17286.6041
# Feature 호선_공항철도1호선, Importance: 51960.1732 ± 38977.9027
# Feature 호선_신분당선(연장2), Importance: 6196.7634 ± 14924.9334
# Feature 호선_1호선, Importance: 3877.9641 ± 9234.5046
# Feature 기준금리, Importance: 0.0000 ± 0.0000
# Feature 신규_가계대출, Importance: -620563.2174 ± 1239745.7137

# %%
df.drop(columns='신규_가계대출', inplace=True)

# %%
import os
import sys
sys.path.append("../../../../../../mnt/workspace/LightGBM/python-package")
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
import warnings
warnings.filterwarnings(action='ignore')

X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2, random_state=42, stratify=df.loc[:,'자치구명']) # train, test set 분리
X_tr, X_val, Y_tr, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42, stratify=X_train['자치구명']) # train, validation set 분리

X_tr.drop(columns='자치구명',inplace=True) # 자치구명 제거
X_val.drop(columns='자치구명',inplace=True) # 자치구명 제거


# 모델 학습
# XGBoost 분류기 초기화
xgb_model= XGBRegressor(
                    tree_method= 'hist',
                    device='cuda',
                    n_estimators= 4000,
                    random_state= 42,
                    enable_categorical= True,
                    early_stopping_rounds= 200
                )

xgb_model.fit(X_tr, Y_tr, eval_set=[(X_val, Y_val)], verbose= False)

# 기본 성능 평가
baseline_score = mean_squared_error(Y_test, xgb_model.predict(X_test.drop(columns='자치구명')), squared=False)
print(f'Baseline Score: {baseline_score:.4f}')


# Permutation Importance 평가
perm_importance = permutation_importance(xgb_model, X_val, Y_val, n_repeats=20, random_state=42, scoring='neg_root_mean_squared_error', n_jobs=-1)

# 변수 중요도 출력
for i in perm_importance.importances_mean.argsort()[::-1]:
    print(f"Feature {X_tr.columns[i]}, Importance: {perm_importance.importances_mean[i]:.4f} ± {perm_importance.importances_std[i]:.4f}")
# Out:
# Baseline Score: 242150497.6462
# Feature 면적코드, Importance: 429993965.7191 ± 11368852.9371
# Feature 15_car, Importance: 310554687.9507 ± 14353689.8235
# Feature 차량접근가능시설수, Importance: 112266455.3856 ± 4698577.8032
# Feature 사용승인일자, Importance: 85521226.8661 ± 6813423.3463
# Feature 승강기수, Importance: 79445502.5335 ± 10288272.2020
# Feature 유소년부양비, Importance: 59861376.9046 ± 2659992.2242
# Feature 30_car, Importance: 55422984.6321 ± 2199265.0470
# Feature 30_walk, Importance: 45679319.9355 ± 1818383.9469
# Feature 인구밀도, Importance: 41366546.2445 ± 2685749.6765
# Feature 호선_분당선, Importance: 33393034.5046 ± 2399478.5695
# Feature 동수, Importance: 28185776.1306 ± 1652136.4677
# Feature 인근-단지 인근표고 최저값, Importance: 28181674.4210 ± 3759519.7399
# Feature 세대수, Importance: 25782924.4615 ± 1531052.3629
# Feature 교차집계구유소년인구수, Importance: 25624998.5557 ± 1829999.4715
# Feature 지하철역까지_거리, Importance: 23199512.8273 ± 1931341.7714
# Feature 5_walk, Importance: 20765317.2922 ± 2463804.6531
# Feature 호선_3호선, Importance: 20754600.2053 ± 1160310.4131
# Feature 20_walk, Importance: 20519379.0325 ± 1888397.3579
# Feature 근접 고도 지점 거리, Importance: 18778198.4447 ± 2237837.7401
# Feature 공원총면적, Importance: 16456247.5426 ± 2165077.1381
# Feature 노령화지수, Importance: 16054759.6353 ± 1517634.8572
# Feature 회전율, Importance: 10501818.0111 ± 1115154.1616
# Feature 누적거래량, Importance: 10149714.5798 ± 2410854.5953
# Feature 아파트단지인근표고평균값, Importance: 9943012.9343 ± 1157636.2789
# Feature 인근-단지 경사도 최고값, Importance: 9919824.0616 ± 931248.4381
# Feature 10_walk, Importance: 8452486.4003 ± 680952.7652
# Feature 아파트단지내표고평균값, Importance: 8159828.5468 ± 2422167.9134
# Feature 교차집계구총인구수, Importance: 7813948.4042 ± 1316370.1123
# Feature 45_car, Importance: 7568455.4709 ± 978058.3909
# Feature 인근-단지 인근표고 평균값, Importance: 7163944.9306 ± 1239213.8616
# Feature 인근-단지 인근표고 최고값, Importance: 6967524.2867 ± 830896.5470
# Feature cpi, Importance: 5924003.7878 ± 1553021.4505
# Feature 기존_가계대출, Importance: 5287159.0405 ± 1323609.9790
# Feature 경제심리지수(원계열), Importance: 4689032.0912 ± 2059114.9736
# Feature 인근-단지 경사도 평균값, Importance: 4369705.8130 ± 512617.2448
# Feature 공원수, Importance: 4207022.2894 ± 1273868.7601
# Feature 교차집계구생산인구수, Importance: 3771069.3249 ± 430554.3850
# Feature 호선_9호선(연장), Importance: 3757167.2643 ± 283450.0469
# Feature 총부양비, Importance: 3654038.0409 ± 1475358.2003
# Feature 교차집계구노년인구수, Importance: 2840569.1482 ± 1143061.2613
# Feature 호선_2호선, Importance: 2494100.3658 ± 299640.3607
# Feature 호선_5호선, Importance: 2468891.3325 ± 262902.1924
# Feature 호선_7호선, Importance: 2273309.1279 ± 785401.9350
# Feature 노년부양비, Importance: 2177022.0510 ± 387339.2116
# Feature 호선_경인선, Importance: 2048495.8577 ± 351979.3993
# Feature 호선_4호선, Importance: 1839928.2112 ± 312542.6741
# Feature 호선_8호선, Importance: 1517340.5211 ± 293506.6437
# Feature 호선_수도권 광역급행철도, Importance: 1156932.1351 ± 192090.3296
# Feature 호선_신분당선, Importance: 936351.3977 ± 118264.9009
# Feature 환경평가점수, Importance: 903638.2827 ± 142964.5524
# Feature 연령구조지표, Importance: 825243.7716 ± 176451.6832
# Feature 호선_9호선, Importance: 814135.8460 ± 250257.7487
# Feature 호선_중앙선, Importance: 738744.9825 ± 320061.6148
# Feature 호선_경원선, Importance: 570183.4633 ± 346522.4108
# Feature 호선_경부선, Importance: 379887.0829 ± 161315.3021
# Feature 호선_우이신설선, Importance: 363889.0463 ± 135712.7755
# Feature 호선_6호선, Importance: 328086.3237 ± 460254.3971
# Feature 호선_경춘선, Importance: 113130.3593 ± 30030.6544
# Feature 호선_경의중앙선, Importance: 35046.4637 ± 86643.2462
# Feature 호선_공항철도1호선, Importance: 32514.4681 ± 40752.3964
# Feature 호선_1호선, Importance: 12709.2116 ± 19103.6347
# Feature 기준금리, Importance: 0.0000 ± 0.0000
# Feature 호선_신분당선(연장2), Importance: -9886.1985 ± 8202.5053
# Feature 인근-단지 경사도 최저값, Importance: -602653.5440 ± 250550.0418

# %%
df.drop(columns='기준금리', inplace=True)

# %%
import os
import sys
sys.path.append("../../../../../../mnt/workspace/LightGBM/python-package")
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
import warnings
warnings.filterwarnings(action='ignore')

X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2, random_state=42, stratify=df.loc[:,'자치구명']) # train, test set 분리
X_tr, X_val, Y_tr, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42, stratify=X_train['자치구명']) # train, validation set 분리

X_tr.drop(columns='자치구명',inplace=True) # 자치구명 제거
X_val.drop(columns='자치구명',inplace=True) # 자치구명 제거


# 모델 학습
# XGBoost 분류기 초기화
xgb_model= XGBRegressor(
                    tree_method= 'hist',
                    device='cuda',
                    n_estimators= 4000,
                    random_state= 42,
                    enable_categorical= True,
                    early_stopping_rounds= 200
                )

xgb_model.fit(X_tr, Y_tr, eval_set=[(X_val, Y_val)], verbose= False)

# 기본 성능 평가
baseline_score = mean_squared_error(Y_test, xgb_model.predict(X_test.drop(columns='자치구명')), squared=False)
print(f'Baseline Score: {baseline_score:.4f}')


# Permutation Importance 평가
perm_importance = permutation_importance(xgb_model, X_val, Y_val, n_repeats=20, random_state=42, scoring='neg_root_mean_squared_error', n_jobs=-1)

# 변수 중요도 출력
for i in perm_importance.importances_mean.argsort()[::-1]:
    print(f"Feature {X_tr.columns[i]}, Importance: {perm_importance.importances_mean[i]:.4f} ± {perm_importance.importances_std[i]:.4f}")
# Out:
# Baseline Score: 242150497.6462
# Feature 면적코드, Importance: 429993965.7191 ± 11368852.9371
# Feature 15_car, Importance: 310554687.9507 ± 14353689.8235
# Feature 차량접근가능시설수, Importance: 112266455.3856 ± 4698577.8032
# Feature 사용승인일자, Importance: 85521226.8661 ± 6813423.3463
# Feature 승강기수, Importance: 79445502.5335 ± 10288272.2020
# Feature 유소년부양비, Importance: 59861376.9046 ± 2659992.2242
# Feature 30_car, Importance: 55422984.6321 ± 2199265.0470
# Feature 30_walk, Importance: 45679319.9355 ± 1818383.9469
# Feature 인구밀도, Importance: 41366546.2445 ± 2685749.6765
# Feature 호선_분당선, Importance: 33393034.5046 ± 2399478.5695
# Feature 동수, Importance: 28185776.1306 ± 1652136.4677
# Feature 인근-단지 인근표고 최저값, Importance: 28181674.4210 ± 3759519.7399
# Feature 세대수, Importance: 25782924.4615 ± 1531052.3629
# Feature 교차집계구유소년인구수, Importance: 25624998.5557 ± 1829999.4715
# Feature 지하철역까지_거리, Importance: 23199512.8273 ± 1931341.7714
# Feature 5_walk, Importance: 20765317.2922 ± 2463804.6531
# Feature 호선_3호선, Importance: 20754600.2053 ± 1160310.4131
# Feature 20_walk, Importance: 20519379.0325 ± 1888397.3579
# Feature 근접 고도 지점 거리, Importance: 18778198.4447 ± 2237837.7401
# Feature 공원총면적, Importance: 16456247.5426 ± 2165077.1381
# Feature 노령화지수, Importance: 16054759.6353 ± 1517634.8572
# Feature 회전율, Importance: 10501818.0111 ± 1115154.1616
# Feature 누적거래량, Importance: 10149714.5798 ± 2410854.5953
# Feature 아파트단지인근표고평균값, Importance: 9943012.9343 ± 1157636.2789
# Feature 인근-단지 경사도 최고값, Importance: 9919824.0616 ± 931248.4381
# Feature 10_walk, Importance: 8452486.4003 ± 680952.7652
# Feature 아파트단지내표고평균값, Importance: 8159828.5468 ± 2422167.9134
# Feature 교차집계구총인구수, Importance: 7813948.4042 ± 1316370.1123
# Feature 45_car, Importance: 7568455.4709 ± 978058.3909
# Feature 인근-단지 인근표고 평균값, Importance: 7163944.9306 ± 1239213.8616
# Feature 인근-단지 인근표고 최고값, Importance: 6967524.2867 ± 830896.5470
# Feature cpi, Importance: 5924003.7878 ± 1553021.4505
# Feature 기존_가계대출, Importance: 5287159.0405 ± 1323609.9790
# Feature 경제심리지수(원계열), Importance: 4689032.0912 ± 2059114.9736
# Feature 인근-단지 경사도 평균값, Importance: 4369705.8130 ± 512617.2448
# Feature 공원수, Importance: 4207022.2894 ± 1273868.7601
# Feature 교차집계구생산인구수, Importance: 3771069.3249 ± 430554.3850
# Feature 호선_9호선(연장), Importance: 3757167.2643 ± 283450.0469
# Feature 총부양비, Importance: 3654038.0409 ± 1475358.2003
# Feature 교차집계구노년인구수, Importance: 2840569.1482 ± 1143061.2613
# Feature 호선_2호선, Importance: 2494100.3658 ± 299640.3607
# Feature 호선_5호선, Importance: 2468891.3325 ± 262902.1924
# Feature 호선_7호선, Importance: 2273309.1279 ± 785401.9350
# Feature 노년부양비, Importance: 2177022.0510 ± 387339.2116
# Feature 호선_경인선, Importance: 2048495.8577 ± 351979.3993
# Feature 호선_4호선, Importance: 1839928.2112 ± 312542.6741
# Feature 호선_8호선, Importance: 1517340.5211 ± 293506.6437
# Feature 호선_수도권 광역급행철도, Importance: 1156932.1351 ± 192090.3296
# Feature 호선_신분당선, Importance: 936351.3977 ± 118264.9009
# Feature 환경평가점수, Importance: 903638.2827 ± 142964.5524
# Feature 연령구조지표, Importance: 825243.7716 ± 176451.6832
# Feature 호선_9호선, Importance: 814135.8460 ± 250257.7487
# Feature 호선_중앙선, Importance: 738744.9825 ± 320061.6148
# Feature 호선_경원선, Importance: 570183.4633 ± 346522.4108
# Feature 호선_경부선, Importance: 379887.0829 ± 161315.3021
# Feature 호선_우이신설선, Importance: 363889.0463 ± 135712.7755
# Feature 호선_6호선, Importance: 328086.3237 ± 460254.3971
# Feature 호선_경춘선, Importance: 113130.3593 ± 30030.6544
# Feature 호선_경의중앙선, Importance: 35046.4637 ± 86643.2462
# Feature 호선_공항철도1호선, Importance: 32514.4681 ± 40752.3964
# Feature 호선_1호선, Importance: 12709.2116 ± 19103.6347
# Feature 호선_신분당선(연장2), Importance: -9886.1985 ± 8202.5053
# Feature 인근-단지 경사도 최저값, Importance: -602653.5440 ± 250550.0418

# %%
df.drop(columns='인근-단지 경사도 최저값', inplace=True)

# %%
import os
import sys
sys.path.append("../../../../../../mnt/workspace/LightGBM/python-package")
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from sklearn.model_selection import train_test_split
from sklearn.inspection import permutation_importance
from sklearn.metrics import mean_squared_error
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.family'] = 'NanumGothic'
plt.rcParams['axes.unicode_minus'] = False
import warnings
warnings.filterwarnings(action='ignore')

X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2, random_state=42, stratify=df.loc[:,'자치구명']) # train, test set 분리
X_tr, X_val, Y_tr, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42, stratify=X_train['자치구명']) # train, validation set 분리

X_tr.drop(columns='자치구명',inplace=True) # 자치구명 제거
X_val.drop(columns='자치구명',inplace=True) # 자치구명 제거


# 모델 학습
# XGBoost 분류기 초기화
xgb_model= XGBRegressor(
                    tree_method= 'hist',
                    device='cuda',
                    n_estimators= 4000,
                    random_state= 42,
                    enable_categorical= True,
                    early_stopping_rounds= 200
                )

xgb_model.fit(X_tr, Y_tr, eval_set=[(X_val, Y_val)], verbose= False)

# 기본 성능 평가
baseline_score = mean_squared_error(Y_test, xgb_model.predict(X_test.drop(columns='자치구명')), squared=False)
print(f'Baseline Score: {baseline_score:.4f}')


# Permutation Importance 평가
perm_importance = permutation_importance(xgb_model, X_val, Y_val, n_repeats=20, random_state=42, scoring='neg_root_mean_squared_error', n_jobs=-1)

# 변수 중요도 출력
for i in perm_importance.importances_mean.argsort()[::-1]:
    print(f"Feature {X_tr.columns[i]}, Importance: {perm_importance.importances_mean[i]:.4f} ± {perm_importance.importances_std[i]:.4f}")
# Out:
# Baseline Score: 245219074.4770
# Feature 면적코드, Importance: 426977059.5562 ± 11230938.3371
# Feature 15_car, Importance: 321403001.9273 ± 14097776.0462
# Feature 차량접근가능시설수, Importance: 194223614.9618 ± 5627342.1997
# Feature 사용승인일자, Importance: 83386796.3933 ± 6766584.7727
# Feature 승강기수, Importance: 82169178.7452 ± 10351813.1501
# Feature 30_car, Importance: 66620666.6483 ± 2112212.8888
# Feature 유소년부양비, Importance: 63516979.0455 ± 3354490.6516
# Feature 45_car, Importance: 49951710.2939 ± 1154693.6592
# Feature 30_walk, Importance: 42747420.9103 ± 2215156.7673
# Feature 인구밀도, Importance: 41333230.2565 ± 2738912.4922
# Feature 인근-단지 인근표고 최저값, Importance: 33723590.6902 ± 3821178.6447
# Feature 호선_분당선, Importance: 32442533.6473 ± 2571234.7261
# Feature 동수, Importance: 29570745.3584 ± 1565221.0308
# Feature 세대수, Importance: 28780083.6620 ± 1659224.7709
# Feature 교차집계구유소년인구수, Importance: 24675151.1812 ± 1740596.4752
# Feature 지하철역까지_거리, Importance: 21437081.5297 ± 1940071.5981
# Feature 호선_3호선, Importance: 19998434.0214 ± 1118936.4776
# Feature 20_walk, Importance: 19933700.0728 ± 2087581.2157
# Feature 근접 고도 지점 거리, Importance: 19606100.4858 ± 2218690.0084
# Feature 5_walk, Importance: 18067994.3473 ± 2441289.2235
# Feature 공원총면적, Importance: 15874264.1764 ± 1990964.0585
# Feature 노령화지수, Importance: 14789087.0473 ± 1395013.6789
# Feature 회전율, Importance: 10356277.3061 ± 1195178.6582
# Feature 아파트단지내표고평균값, Importance: 9700567.8873 ± 2339363.5354
# Feature 인근-단지 경사도 최고값, Importance: 8680773.2575 ± 1158090.6973
# Feature 아파트단지인근표고평균값, Importance: 8388362.8839 ± 1197431.6427
# Feature 10_walk, Importance: 7816427.3814 ± 726342.0225
# Feature 누적거래량, Importance: 7002038.7040 ± 2950244.8708
# Feature cpi, Importance: 6576425.0282 ± 1357305.9089
# Feature 인근-단지 인근표고 평균값, Importance: 6548200.0963 ± 1137882.1971
# Feature 기존_가계대출, Importance: 5880471.6839 ± 1512954.2868
# Feature 인근-단지 인근표고 최고값, Importance: 5147692.7731 ± 773939.1612
# Feature 교차집계구총인구수, Importance: 4842174.2416 ± 1265973.7081
# Feature 경제심리지수(원계열), Importance: 4784911.7555 ± 2165505.1845
# Feature 인근-단지 경사도 평균값, Importance: 3703440.3881 ± 491651.4244
# Feature 호선_9호선(연장), Importance: 3644304.3711 ± 240101.0325
# Feature 노년부양비, Importance: 3456996.1382 ± 1142132.9458
# Feature 총부양비, Importance: 3421987.1473 ± 1723843.0882
# Feature 호선_2호선, Importance: 3267112.8985 ± 261625.1084
# Feature 공원수, Importance: 2747577.8562 ± 1297405.2491
# Feature 호선_4호선, Importance: 2730167.4602 ± 468815.9054
# Feature 호선_5호선, Importance: 2680323.2024 ± 221515.7661
# Feature 교차집계구생산인구수, Importance: 2311404.9429 ± 446108.7785
# Feature 교차집계구노년인구수, Importance: 1964633.5577 ± 796113.5743
# Feature 호선_경인선, Importance: 1831063.6433 ± 352253.5567
# Feature 호선_신분당선, Importance: 1551827.7866 ± 251128.8791
# Feature 호선_8호선, Importance: 1230726.9079 ± 267356.9721
# Feature 호선_수도권 광역급행철도, Importance: 930857.6624 ± 161660.9061
# Feature 연령구조지표, Importance: 841680.5266 ± 112395.9565
# Feature 호선_경원선, Importance: 835325.7204 ± 405388.8787
# Feature 호선_9호선, Importance: 808178.5626 ± 289212.1898
# Feature 호선_중앙선, Importance: 584488.5821 ± 193707.7584
# Feature 환경평가점수, Importance: 510138.6234 ± 145893.7056
# Feature 호선_6호선, Importance: 452979.9823 ± 275011.2967
# Feature 호선_경부선, Importance: 387867.9823 ± 176432.8682
# Feature 호선_7호선, Importance: 303768.1458 ± 137010.7115
# Feature 호선_우이신설선, Importance: 289657.6801 ± 138680.5069
# Feature 호선_경춘선, Importance: 145656.8819 ± 54046.4832
# Feature 호선_공항철도1호선, Importance: 59859.8568 ± 41013.6943
# Feature 호선_1호선, Importance: 34948.0906 ± 12370.3709
# Feature 호선_신분당선(연장2), Importance: 11620.2544 ± 11063.7953
# Feature 호선_경의중앙선, Importance: 11175.9938 ± 22692.4390

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29335 entries, 115 to 385487
# Data columns (total 64 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   면적코드            29335 non-null  int64
#  1   누적거래량           29335 non-null  int64
#  2   회전율             29335 non-null  float64
#  3   세대수             29250 non-null  float64
#  4   사용승인일자          29195 non-null  float64
#  5   동수              28356 non-null  float64
#  6   승강기수            28356 non-null  float64
#  7   교차집계구총인구수       29316 non-null  float64
#  8   교차집계구생산인구수      29316 non-null  float64
#  9   교차집계구유소년인구수     29316 non-null  float64
#  10  교차집계구노년인구수      29316 non-null  float64
#  11  인구밀도            29316 non-null  float64
#  12  총부양비            29320 non-null  float64
#  13  유소년부양비          29320 non-null  float64
#  14  노년부양비           29320 non-null  float64
#  15  노령화지수           29320 non-null  float64
#  16  연령구조지표          29320 non-null  float64
#  17  지하철역까지_거리       29335 non-null  float64
#  18  공원수             29335 non-null  int64
#  19  공원총면적           29335 non-null  float64
#  20  환경평가점수          29335 non-null  int64
#  21  차량접근가능시설수       29335 non-null  int64
#  22  아파트단지내표고평균값     29335 non-null  float64
#  23  아파트단지인근표고평균값    29335 non-null  float64
#  24  근접 고도 지점 거리     29335 non-null  float64
#  25  cpi             29335 non-null  float64
#  26  경제심리지수(원계열)     29335 non-null  float64
#  27  기존_가계대출         29335 non-null  float64
#  28  15_car          29335 non-null  int64
#  29  30_car          29335 non-null  int64
#  30  45_car          29335 non-null  int64
#  31  5_walk          29335 non-null  int64
#  32  10_walk         29335 non-null  int64
#  33  20_walk         29335 non-null  int64
#  34  30_walk         29335 non-null  int64
#  35  자치구명            29335 non-null  object
#  36  인근-단지 경사도 평균값   29335 non-null  float64
#  37  인근-단지 경사도 최고값   29335 non-null  float64
#  38  인근-단지 인근표고 평균값  29335 non-null  float64
#  39  인근-단지 인근표고 최저값  29335 non-null  float64
#  40  인근-단지 인근표고 최고값  29335 non-null  float64
#  41  호선_1호선          29335 non-null  uint8
#  42  호선_2호선          29335 non-null  uint8
#  43  호선_3호선          29335 non-null  uint8
#  44  호선_4호선          29335 non-null  uint8
#  45  호선_5호선          29335 non-null  uint8
#  46  호선_6호선          29335 non-null  uint8
#  47  호선_7호선          29335 non-null  uint8
#  48  호선_8호선          29335 non-null  uint8
#  49  호선_9호선          29335 non-null  uint8
#  50  호선_9호선(연장)      29335 non-null  uint8
#  51  호선_경부선          29335 non-null  uint8
#  52  호선_경원선          29335 non-null  uint8
#  53  호선_경의중앙선        29335 non-null  uint8
#  54  호선_경인선          29335 non-null  uint8
#  55  호선_경춘선          29335 non-null  uint8
#  56  호선_공항철도1호선      29335 non-null  uint8
#  57  호선_분당선          29335 non-null  uint8
#  58  호선_수도권 광역급행철도   29335 non-null  uint8
#  59  호선_신분당선         29335 non-null  uint8
#  60  호선_신분당선(연장2)    29335 non-null  uint8
#  61  호선_우이신설선        29335 non-null  uint8
#  62  호선_중앙선          29335 non-null  uint8
#  63  target          29335 non-null  int64
# dtypes: float64(28), int64(13), object(1), uint8(22)
# memory usage: 10.2+ MB

# %%
model= XGBRegressor(
                    tree_method= 'hist',
                    device='cuda',
                    n_estimators= 4000,
                    random_state= 42
                )


X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2, random_state=42, stratify=df.loc[:,'자치구명']) # train, test set 분리
X_tr, X_val, Y_tr, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42, stratify=X_train['자치구명']) # train, validation set 분리

X_tr.drop(columns='자치구명',inplace=True) # 자치구명 제거
X_val.drop(columns='자치구명',inplace=True) # 자치구명 제거

model.fit(X_tr, Y_tr, eval_set=[(X_tr, Y_tr),(X_val, Y_val)], eval_metric='rmse', early_stopping_rounds=200, verbose= False) # 모델 학습
print(mean_squared_error(Y_test, model.predict(X_test.drop(columns='자치구명')), squared=False)) # test set에 대한 rmse 출력
# Out:
# 245219074.47696805

# %% [markdown]
# ##### 부분의존도 plot

# %%
from sklearn.model_selection import train_test_split
import pandas as pd

model= XGBRegressor(
                    tree_method= 'hist',
                    device='cuda',
                    n_estimators= 4000,
                    random_state= 42
                )


X_train, X_test, Y_train, Y_test = train_test_split(df.iloc[:,:-1], df.iloc[:,-1], test_size=0.2, random_state=42, stratify=df.loc[:,'자치구명']) # train, test set 분리
X_tr, X_val, Y_tr, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42, stratify=X_train['자치구명']) # train, validation set 분리

X_tr.drop(columns='자치구명',inplace=True) # 자치구명 제거
X_val.drop(columns='자치구명',inplace=True) # 자치구명 제거


model.fit(X_tr, Y_tr, eval_set=[(X_tr, Y_tr),(X_val, Y_val)], eval_metric='rmse', early_stopping_rounds=300, verbose= False) # 모델 학습
y_pred = model.predict(X_test.drop(columns='자치구명'))

rmse = mean_squared_error(Y_test, model.predict(X_test.drop(columns='자치구명')), squared=False)
print(f'RMSE: {rmse:.2f}')
# Out:
# RMSE: 245219074.48

# %%
import shap



# SHAP 값 계산
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test.drop(columns='자치구명'))
shap.summary_plot(shap_values, X_test.drop(columns='자치구명'))

# %%
from sklearn.inspection import PartialDependenceDisplay
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings(action='ignore')


# SHAP 값 계산
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test.drop(columns='자치구명'))

feature_importance = np.abs(shap_values).mean(0)
feature_importance_df = pd.DataFrame({
    'feature': X_test.drop(columns='자치구명').columns,
    'importance': feature_importance
})

top_20_features = feature_importance_df.sort_values('importance', ascending=False).head(20)
features = top_20_features['feature'].tolist()




# 부분 의존성 플롯 생성
fig, ax = plt.subplots(4, 5, figsize=(30, 28))
display = PartialDependenceDisplay.from_estimator(
    model,
    X_test.drop(columns='자치구명'),
    features,
    kind="average",
    subsample=1000,
    n_jobs=-1,
    grid_resolution=20,
    random_state=42,
    ax=ax
)
fig.suptitle("Partial Dependence Plots")
plt.tight_layout()
plt.show()

# %%
import warnings
warnings.filterwarnings(action='ignore')

def local_train(local):
    print(f"\n=== {local} 분석 결과 ===")
    
    df_local = df[df['자치구명']==local].copy()
    df_local.drop(columns='자치구명',inplace=True)
    
    model = XGBRegressor(
        tree_method='hist',
        device='cuda',
        n_estimators=4000,
        random_state=42
    )

    X_train, X_test, Y_train, Y_test = train_test_split(df_local.iloc[:,:-1], df_local.iloc[:,-1], test_size=0.2, random_state=42)
    X_tr, X_val, Y_tr, Y_val = train_test_split(X_train, Y_train, test_size=0.2, random_state=42)

    model.fit(X_tr, Y_tr, eval_set=[(X_tr, Y_tr),(X_val, Y_val)], eval_metric='rmse', early_stopping_rounds=300, verbose=False)
    rmse = mean_squared_error(Y_test, model.predict(X_test), squared=False)
    print(f'RMSE: {rmse:.3f}')

    # SHAP 값 계산
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_test)
    
    feature_importance = np.abs(shap_values).mean(0)
    feature_importance_df = pd.DataFrame({
        'feature': X_test.columns,
        'importance': feature_importance
    })
    
    top_20_features = feature_importance_df.sort_values('importance', ascending=False).head(20)
    features = top_20_features['feature'].tolist()

    # 부분 의존성 플롯 생성
    plt.figure(figsize=(20, 15))
    fig, ax = plt.subplots(4, 5, figsize=(10, 10))
    display = PartialDependenceDisplay.from_estimator(
        model,
        X_test,
        features,
        kind="average",
        subsample=1000,
        n_jobs=-1,
        grid_resolution=20,
        random_state=42,
        ax=ax
    )
    fig.suptitle(f"{local} - Partial Dependence Plots", fontsize=16)
    plt.tight_layout()
    plt.show()

# 모든 자치구에 대해 실행
unique_locals = df['자치구명'].unique()
for local in unique_locals:
    local_train(local)
# Out:
# === 종로구 분석 결과 ===
# RMSE: 185410264.285
# === 중구 분석 결과 ===
# RMSE: 165955733.580
# === 용산구 분석 결과 ===
# RMSE: 550788087.237
# === 성동구 분석 결과 ===
# RMSE: 558369441.821
# === 광진구 분석 결과 ===
# RMSE: 292940054.412
# === 동대문구 분석 결과 ===
# RMSE: 75474805.672
# === 중랑구 분석 결과 ===
# RMSE: 93754989.961
# === 성북구 분석 결과 ===
# RMSE: 67869686.985
# === 강북구 분석 결과 ===
# RMSE: 90188096.817
# === 도봉구 분석 결과 ===
# RMSE: 92091864.884
# === 노원구 분석 결과 ===
# RMSE: 66947104.579
# === 은평구 분석 결과 ===
# RMSE: 95370292.811
# === 서대문구 분석 결과 ===
# RMSE: 149224305.093
# === 마포구 분석 결과 ===
# RMSE: 122633726.092
# === 양천구 분석 결과 ===
# RMSE: 122084749.528
# === 강서구 분석 결과 ===
# RMSE: 94196109.102
# === 구로구 분석 결과 ===
# RMSE: 84818015.362
# === 금천구 분석 결과 ===
# RMSE: 67666490.169
# === 영등포구 분석 결과 ===
# RMSE: 178325404.035
# === 동작구 분석 결과 ===
# RMSE: 134760801.559
# === 관악구 분석 결과 ===
# RMSE: 95962414.639
# === 서초구 분석 결과 ===
# RMSE: 464939175.331
# === 강남구 분석 결과 ===
# RMSE: 619759335.724
# === 송파구 분석 결과 ===
# RMSE: 191619213.911
# === 강동구 분석 결과 ===
# RMSE: 93427027.791
